# %%
import pandas as pd
from kite_trade import *

# %%
data = pd.read_excel("EOD.xlsm")

# %%
data
# Out:
#                                             Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0    Breakout Filtering Utility\n\nby Vinay Kumar\n...        NaN        NaN
# 1                                                  NaN        NaN        NaN
# 2                                                  NaN        NaN        NaN
# 3                                                  NaN        NaN        NaN
# 4                                                  NaN        NaN        NaN
# ..                                                 ...        ...        ...
# 502                                                NaN        NaN        NaN
# 503                                                NaN        NaN        NaN
# 504                                                NaN        NaN        NaN
# 505                                                NaN        NaN        NaN
# 506                                                NaN        NaN
#
#     Unnamed: 3 Unnamed: 4  Unnamed: 5      Breakout Filter    Unnamed: 7  \
# 0                             Scripts  2022-10-18 00:00:00        Candle
# 1     NIFTY 50          1  ADANIPORTS          no breakout  Green candle
# 2     NIFTY 50          2  ASIANPAINT          no breakout  Green candle
# 3     NIFTY 50          3    AXISBANK           Red candle    Red candle
# 4     NIFTY 50          4  BAJAJ-AUTO           Red candle    Red candle
# ..         ...        ...         ...                  ...           ...
# 502        NaN        NaN         NaN                  NaN           NaN
# 503        NaN        NaN         NaN                  NaN           NaN
# 504        NaN        NaN         NaN                  NaN           NaN
# 505        NaN        NaN         NaN                  NaN           NaN
# 506        NaN        NaN         NaN                  NaN           NaN
#
#     Unnamed: 8    Unnamed: 9   Unnamed: 10  Unnamed: 11    Unnamed: 12  \
# 0       Volume  Present Open  Present High  Present Low  Present Close
# 1      Average        791.45           815        790.5         809.95
# 2          Low          3218          3250         3212        3225.85
# 3          Low           820         822.9       811.55         816.35
# 4      Average       3647.15       3664.85       3602.1         3611.3
# ..         ...           ...           ...          ...            ...
# 502        NaN           NaN           NaN          NaN            NaN
# 503        NaN           NaN           NaN          NaN            NaN
# 504        NaN           NaN           NaN          NaN            NaN
# 505        NaN           NaN           NaN          NaN            NaN
# 506        NaN           NaN           NaN          NaN            NaN
#
#     Unnamed: 13  Unnamed: 14                   Unnamed: 15
# 0     Prev High  Present Vol              Check Chart Here
# 1        811.75      7372253  click here to view the chart
# 2        3339.5      1015424  click here to view the chart
# 3         820.7      8470882  click here to view the chart
# 4        3674.8       496519  click here to view the chart
# ..          ...          ...                           ...
# 502         NaN          NaN                           NaN
# 503         NaN          NaN                           NaN
# 504         NaN          NaN                           NaN
# 505         NaN          NaN                           NaN
# 506         NaN          NaN                           NaN
#
# [507 rows x 16 columns]

# %%
data = data.iloc[1:493, 5:15]

# %%
filt = (data["Breakout Filter"] == "Breakout") & (data["Unnamed: 7"] == "Green candle") & (data["Unnamed: 8"] == "Good")
stocks_EOD = data[filt]["Unnamed: 5"]
stock_sls = data[filt]["Unnamed: 11"]

# %%
stocks = stocks_EOD.to_list()
sls = stock_sls.to_list()
stocks
# Out:
# ['ITC',
#  'BHEL',
#  'CANBK',
#  'PNB',
#  'TVSMOTOR',
#  'POLYCAB',
#  'UNIONBANK',
#  'CANFINHOME',
#  'KARURVYSYA',
#  'MAHLOG',
#  'NETWORK18',
#  'UFLEX']

# %%
stocks
